# %% [markdown]
# # Car Sales Analysis & Preediction

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Step 1: Load the dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Step 2: Data Loading

# %%
file_path = 'linear_regression_car_sales.xlsx'

sheet_name = 'car_sales'

df = pd.read_excel(file_path, sheet_name = sheet_name)

# %%
df
# Out:
#              Car_id                 Date Customer Name  Gender  Annual Income  \
# 0      C_CND_000001  2022-02-01 00:00:00     Geraldine    Male          13500
# 1      C_CND_000002  2022-02-01 00:00:00           Gia    Male        1480000
# 2      C_CND_000003  2022-02-01 00:00:00        Gianna    Male        1035000
# 3      C_CND_000004  2022-02-01 00:00:00       Giselle    Male          13500
# 4      C_CND_000005  2022-02-01 00:00:00         Grace    Male        1465000
# ...             ...                  ...           ...     ...            ...
# 23901  C_CND_023902           12/31/2023        Martin    Male          13500
# 23902  C_CND_023903           12/31/2023         Jimmy  Female         900000
# 23903  C_CND_023904           12/31/2023          Emma    Male         705000
# 23904  C_CND_023905           12/31/2023      Victoire    Male          13500
# 23905  C_CND_023906           12/31/2023       Donovan    Male        1225000
#
# ...

# %%
# Display the top 5 record of the data
df.head()
# Out:
#          Car_id                 Date Customer Name Gender  Annual Income  \
# 0  C_CND_000001  2022-02-01 00:00:00     Geraldine   Male          13500
# 1  C_CND_000002  2022-02-01 00:00:00           Gia   Male        1480000
# 2  C_CND_000003  2022-02-01 00:00:00        Gianna   Male        1035000
# 3  C_CND_000004  2022-02-01 00:00:00       Giselle   Male          13500
# 4  C_CND_000005  2022-02-01 00:00:00         Grace   Male        1465000
#
#                            Dealer_Name   Company       Model  \
# 0  Buddy Storbeck's Diesel Service Inc      Ford  Expedition
# 1                     C & M Motors Inc     Dodge     Durango
# 2                          Capitol KIA  Cadillac    Eldorado
# 3               Chrysler of Tri-Cities    Toyota      Celica
# 4                    Chrysler Plymouth     Acura          TL
#
#                         Engine Transmission       Color  Sales ($)  \
# 0  DoubleÃ‚Â Overhead Camshaft         Auto       Black      26000
# ...

# %%
# Display the last 5 records of the data
df.tail()
# Out:
#              Car_id        Date Customer Name  Gender  Annual Income  \
# 23901  C_CND_023902  12/31/2023        Martin    Male          13500
# 23902  C_CND_023903  12/31/2023         Jimmy  Female         900000
# 23903  C_CND_023904  12/31/2023          Emma    Male         705000
# 23904  C_CND_023905  12/31/2023      Victoire    Male          13500
# 23905  C_CND_023906  12/31/2023       Donovan    Male        1225000
#
#                           Dealer_Name    Company    Model  \
# 23901                C & M Motors Inc   Plymouth  Voyager
# 23902  Ryder Truck Rental and Leasing  Chevrolet    Prizm
# 23903          Chrysler of Tri-Cities        BMW     328i
# 23904               Chrysler Plymouth  Chevrolet    Metro
# 23905                 Pars Auto Sales      Lexus    ES300
#
#                             Engine Transmission       Color  Sales ($)  \
# 23901            Overhead Camshaft       Manual         Red      12000
# ...

# %%
# Information about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23906 entries, 0 to 23905
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_id         23906 non-null  object
#  1   Date           23906 non-null  object
#  2   Customer Name  23906 non-null  object
#  3   Gender         23906 non-null  object
#  4   Annual Income  23906 non-null  int64
#  5   Dealer_Name    23906 non-null  object
#  6   Company        23906 non-null  object
#  7   Model          23906 non-null  object
#  8   Engine         23906 non-null  object
#  9   Transmission   23906 non-null  object
#  10  Color          23906 non-null  object
#  11  Sales ($)      23906 non-null  int64
#  12  Dealer_No      23906 non-null  object
#  13  Body Style     23906 non-null  object
#  14  Phone          23906 non-null  int64
#  15  Dealer_Region  23906 non-null  object
# dtypes: int64(3), object(13)
# memory usage: 2.9+ MB

# %%
# Descriptive statistics of the data
df.describe()
# Out:
#        Annual Income     Sales ($)         Phone
# count   2.390600e+04  23906.000000  2.390600e+04
# mean    8.308403e+05  28090.247846  7.497741e+06
# std     7.200064e+05  14788.687608  8.674920e+05
# min     1.008000e+04   1200.000000  6.000101e+06
# 25%     3.860000e+05  18001.000000  6.746495e+06
# 50%     7.350000e+05  23000.000000  7.496198e+06
# 75%     1.175750e+06  34000.000000  8.248146e+06
# max     1.120000e+07  85800.000000  8.999579e+06

# %%
# Shape of the data
df.shape
# Out:
# (23906, 16)

# %%
# Check for missing values 
df.isnull().sum()
# Out:
# Car_id           0
# Date             0
# Customer Name    0
# Gender           0
# Annual Income    0
# Dealer_Name      0
# Company          0
# Model            0
# Engine           0
# Transmission     0
# Color            0
# Sales ($)        0
# Dealer_No        0
# Body Style       0
# Phone            0
# Dealer_Region    0
# dtype: int64

# %% [markdown]
# ## Data Transformation/Wrangling

# %%
df.columns
# Out:
# Index(['Car_id', 'Date', 'Customer Name', 'Gender', 'Annual Income',
#        'Dealer_Name', 'Company', 'Model', 'Engine', 'Transmission', 'Color',
#        'Sales ($)', 'Dealer_No ', 'Body Style', 'Phone', 'Dealer_Region'],
#       dtype='object')

# %%
# Displaying the datatypes
df.dtypes
# Out:
# Car_id           object
# Date             object
# Customer Name    object
# Gender           object
# Annual Income     int64
# Dealer_Name      object
# Company          object
# Model            object
# Engine           object
# Transmission     object
# Color            object
# Sales ($)         int64
# Dealer_No        object
# Body Style       object
# Phone             int64
# Dealer_Region    object
# dtype: object

# %%
# Converting column names to lower case
df.columns = df.columns.str.lower()
df.columns
# Out:
# Index(['car_id', 'date', 'customer name', 'gender', 'annual income',
#        'dealer_name', 'company', 'model', 'engine', 'transmission', 'color',
#        'sales ($)', 'dealer_no ', 'body style', 'phone', 'dealer_region'],
#       dtype='object')

# %%
# Converting the date column to a proper date-time column

df['date'] = pd.to_datetime(df['date'], format = '%d/%m/%Y')
df['date']
# Out:
# 0       2022-02-01
# 1       2022-02-01
# 2       2022-02-01
# 3       2022-02-01
# 4       2022-02-01
#            ...
# 23901   2023-12-31
# 23902   2023-12-31
# 23903   2023-12-31
# 23904   2023-12-31
# 23905   2023-12-31
# Name: date, Length: 23906, dtype: datetime64[ns]

# %%
# Checking the datatype again
df.dtypes
# Out:
# car_id                   object
# date             datetime64[ns]
# customer name            object
# gender                   object
# annual income             int64
# dealer_name              object
# company                  object
# model                    object
# engine                   object
# transmission             object
# color                    object
# sales ($)                 int64
# dealer_no                object
# body style               object
# phone                     int64
# dealer_region            object
# dtype: object

# %% [markdown]
# ## Step 3: Exploratory Data Analysis (EDA)

# %%
df.head()
# Out:
#          car_id       date customer name gender  annual income  \
# 0  C_CND_000001 2022-02-01     Geraldine   Male          13500
# 1  C_CND_000002 2022-02-01           Gia   Male        1480000
# 2  C_CND_000003 2022-02-01        Gianna   Male        1035000
# 3  C_CND_000004 2022-02-01       Giselle   Male          13500
# 4  C_CND_000005 2022-02-01         Grace   Male        1465000
#
#                            dealer_name   company       model  \
# 0  Buddy Storbeck's Diesel Service Inc      Ford  Expedition
# 1                     C & M Motors Inc     Dodge     Durango
# 2                          Capitol KIA  Cadillac    Eldorado
# 3               Chrysler of Tri-Cities    Toyota      Celica
# 4                    Chrysler Plymouth     Acura          TL
#
#                         engine transmission       color  sales ($)  \
# 0  DoubleÃ‚Â Overhead Camshaft         Auto       Black      26000
# 1  DoubleÃ‚Â Overhead Camshaft         Auto       Black      19000
# ...

# %%
# Which gender purchased more cars

print(df['gender'].value_counts())

plt.figure(figsize = (12,4))

df['gender'].value_counts().plot(kind = 'bar')

plt.title('Distribution of gender', color = 'red')

plt.ylabel('Gender frequency')
# Out:
# Male      18798
# Female     5108
# Name: gender, dtype: int64
# Text(0, 0.5, 'Gender frequency')

# %%
# Dealer with the highest purchase 

df['dealer_name'].value_counts()
# Out:
# Progressive Shippers Cooperative Association No    1318
# Rabun Used Car Sales                               1313
# Race Car Help                                      1253
# Saab-Belle Dodge                                   1251
# Star Enterprises Inc                               1249
# Tri-State Mack Inc                                 1249
# Ryder Truck Rental and Leasing                     1248
# U-Haul CO                                          1247
# Scrivener Performance Engineering                  1246
# Suburban Ford                                      1243
# Nebo Chevrolet                                      633
# Pars Auto Sales                                     630
# New Castle Ford Lincoln Mercury                     629
# McKinney Dodge Chrysler Jeep                        629
# Hatfield Volkswagen                                 629
# Gartner Buick Hyundai Saab                          628
# Pitre Buick-Pontiac-Gmc of Scottsdale               628
# ...

# %%
print(df['dealer_name'].value_counts().head())

plt.figure(figsize = (12, 4))

df['dealer_name'].value_counts().head().plot(kind = 'bar')

plt.title('Top 5 dealers with the highest purchase', color = 'red')

plt.ylabel('Frequency')
# Out:
# Progressive Shippers Cooperative Association No    1318
# Rabun Used Car Sales                               1313
# Race Car Help                                      1253
# Saab-Belle Dodge                                   1251
# Star Enterprises Inc                               1249
# Name: dealer_name, dtype: int64
# Text(0, 0.5, 'Frequency')

# %%
# What is the most purchased car color

print(df['color'].value_counts())

color = ['blue', 'gold', 'red']

df['color'].value_counts().plot(kind = 'pie', colors = color, autopct = '%1.1f%%')
# Out:
# Pale White    11256
# Black          7857
# Red            4793
# Name: color, dtype: int64
# <AxesSubplot:ylabel='color'>

# %%
df.columns
# Out:
# Index(['car_id', 'date', 'customer name', 'gender', 'annual income',
#        'dealer_name', 'company', 'model', 'engine', 'transmission', 'color',
#        'sales ($)', 'dealer_no ', 'body style', 'phone', 'dealer_region'],
#       dtype='object')

# %%
# Sales by Gender

print(df.groupby('gender')['sales ($)'].sum())

color = ['red', 'green']

df.groupby('gender')['sales ($)'].sum().plot(kind = 'pie', colors = color, autopct = '%1.1f%%')
# Out:
# gender
# Female    144440271
# Male      527085194
# Name: sales ($), dtype: int64
# <AxesSubplot:ylabel='sales ($)'>

# %% [markdown]
# ## Correlation

# %%
# Selecting only the numerical columns

numerical_columns = df.select_dtypes(include = ['int', 'float'])

# numerical_columns = df.select_dtypes(exclude = 'objects') --> To remove object datatypes

numerical_columns
# Out:
#        annual income  sales ($)    phone
# 0              13500      26000  8264678
# 1            1480000      19000  6848189
# 2            1035000      31500  7298798
# 3              13500      14000  6257557
# 4            1465000      24500  7081483
# ...              ...        ...      ...
# 23901          13500      12000  8583598
# 23902         900000      16000  7914229
# 23903         705000      21000  7659127
# 23904          13500      31000  6030764
# 23905        1225000      27500  7020564
#
# [23906 rows x 3 columns]

# %%
numerical_columns.drop('phone', axis = 1, inplace = True)

# %%
numerical_columns
# Out:
#        annual income  sales ($)
# 0              13500      26000
# 1            1480000      19000
# 2            1035000      31500
# 3              13500      14000
# 4            1465000      24500
# ...              ...        ...
# 23901          13500      12000
# 23902         900000      16000
# 23903         705000      21000
# 23904          13500      31000
# 23905        1225000      27500
#
# [23906 rows x 2 columns]

# %%
# Is the annual income affecting the sales

numerical_columns.corr()
# Out:
#                annual income  sales ($)
# annual income       1.000000   0.012065
# sales ($)           0.012065   1.000000

# %% [markdown]
# ##  Step 4: Data Preparation for Prediction

# %%
df.columns
# Out:
# Index(['car_id', 'date', 'customer name', 'gender', 'annual income',
#        'dealer_name', 'company', 'model', 'engine', 'transmission', 'color',
#        'sales ($)', 'dealer_no ', 'body style', 'phone', 'dealer_region'],
#       dtype='object')

# %%
# Creating a new dataframe

df2 = df.drop(['car_id', 'date', 'customer name', 'dealer_name', 'dealer_no ', 'phone', 'engine', 'company'], axis = 1)
df2
# Out:
#        gender  annual income       model transmission       color  sales ($)  \
# 0        Male          13500  Expedition         Auto       Black      26000
# 1        Male        1480000     Durango         Auto       Black      19000
# 2        Male        1035000    Eldorado       Manual         Red      31500
# 3        Male          13500      Celica       Manual  Pale White      14000
# 4        Male        1465000          TL         Auto         Red      24500
# ...       ...            ...         ...          ...         ...        ...
# 23901    Male          13500     Voyager       Manual         Red      12000
# 23902  Female         900000       Prizm         Auto       Black      16000
# 23903    Male         705000        328i       Manual         Red      21000
# 23904    Male          13500       Metro         Auto       Black      31000
# 23905    Male        1225000       ES300         Auto  Pale White      27500
#
#       body style dealer_region
# ...

# %% [markdown]
# ## Splitting the data into dependent and independent variable

# %%
dependent = df2['sales ($)']
independent = df2.drop(['sales ($)', 'model', 'dealer_region'], axis = 1)

# %%
# Pasing into X and y
X = independent
y = dependent

# %%
X.head()
# Out:
#   gender  annual income transmission       color body style
# 0   Male          13500         Auto       Black        SUV
# 1   Male        1480000         Auto       Black        SUV
# 2   Male        1035000       Manual         Red  Passenger
# 3   Male          13500       Manual  Pale White        SUV
# 4   Male        1465000         Auto         Red  Hatchback

# %% [markdown]
# ## Step 5: Data Processing

# %% [markdown]
# ### 5.1 Encoding the categorical column to numbers

# %%
# Encoding the gender column
X['gender'] = df['gender'].map({
    'Male': 1,
    'Female': 0
})

# Encoding the transmission column
X['transmission'] = df['transmission'].map({
    'Auto': 1,
    'Manual': 0
})

# Encoding the color column
X['color'] = df['color'].map({
    'Pale White': 0,
    'Red': 1,
    'Black': 2
})

# Encoding the body style column
X['body style']= df['body style'].map({
    'SUV': 0,
    'Passenger': 1,
    'Hatchback': 2,
    'Hardtop': 3,
    'Sedan': 4
})

# %%
X.head()
# Out:
#    gender  annual income  transmission  color  body style
# 0       1          13500             1      2           0
# 1       1        1480000             1      2           0
# 2       1        1035000             0      1           1
# 3       1          13500             0      0           0
# 4       1        1465000             1      1           2

# %% [markdown]
# ### 5.2 Scaling the data using standard scaler

# %%
from sklearn.preprocessing import StandardScaler      #MinMaxScaler

scaler = StandardScaler()
scaler
# Out:
# StandardScaler()

# %%
# Fit & Transform our X variable
scaledX = scaler.fit_transform(X)
scaledX
# Out:
# array([[ 0.52127827, -1.1352085 ,  0.94956752,  1.29385472, -1.2529157 ],
#        [ 0.52127827,  0.90162156,  0.94956752,  1.29385472, -1.2529157 ],
#        [ 0.52127827,  0.28355857, -1.053111  ,  0.16106252, -0.55742035],
#        ...,
#        [ 0.52127827, -0.17478028, -1.053111  ,  0.16106252,  1.5290657 ],
#        [ 0.52127827, -1.1352085 ,  0.94956752,  1.29385472, -0.55742035],
#        [ 0.52127827,  0.54745064,  0.94956752, -0.97172968,  0.83357035]])

# %% [markdown]
# ### 5.3 Split into training and testing set

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(scaledX, y, test_size = 0.2, random_state = 42)

display(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (19124, 5)
# (4782, 5)
# (19124,)
# (4782,)

# %% [markdown]
# ### 5.4 Model Build --> Linear Regression

# %%
from sklearn.linear_model import LinearRegression

regress = LinearRegression()
regress
# Out:
# LinearRegression()

# %%
regress.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regress.predict(X_test)
display(y_test, y_pred)
# Out:
# 3393     19500
# 516      46000
# 536      39000
# 16108    17500
# 18911    22000
#          ...
# 16796    27000
# 16839    20001
# 15003    15000
# 3171     82000
# 13053    25000
# Name: sales ($), Length: 4782, dtype: int64
# array([28681.85575075, 28372.91678253, 28544.24951804, ...,
#        29141.77726887, 27534.43221975, 26605.90249948])

# %%
from sklearn.metrics import r2_score

# %%
print(r2_score(y_test, y_pred))
# Out:
# 0.00512617654846792

# %%
regress.score(X_train, y_train)
# Out:
# 0.00556287722235127

# %% [markdown]
# ### The model did not perform well, which means we cannot deploy this model... Looking at the score, we cannot make use of the model in predicting the sales of the company.
